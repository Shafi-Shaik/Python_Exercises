# %%
import requests
import os
import pandas as pd

# %%
API_TOKEN=os.environ.get('API_KEY')
include='local'
url=f'https://cricket.sportmonks.com/api/v2.0/players?api_token={API_TOKEN}'

# %%
rsp = requests.get(url)

# %%
match rsp.status_code:
    case 200:
        print("Successful request and data was returned")

    case 400:
        print("Part of the request is malformed; the exact reason can be found in the response")

    case 401:
        print("Request is not authenticated")
    
    case 403:
        print("Unauthorized request to access data from an ineligible plan")

    case 429:
        print("You have reached the response rate limit of your plan")
    case 500:
        print("Internal error with our servers")
    case _:
        print('not in switch statement')
# Out:
# Successful request and data was returned

# %%
#print(dir(rsp))

# %%
headers=rsp.headers
headers
# Out:
# {'Date': 'Wed, 11 Jan 2023 10:47:06 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Cache-Control': 'no-cache, private', 'x-ratelimit-limit': '180', 'x-ratelimit-remaining': '176', 'strict-transport-security': 'max-age=31536000', 'vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'CF-Cache-Status': 'DYNAMIC', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=Z6iHHqsRuMTa7UjJ3Ff%2FCKaWorL5LYicfssCe0t5ZAKVAHqV8BUqFrfe9knbLMKf3MwI0eu%2FUzQjHNyUf28WL%2F%2FKyKkhLC4jIiKafUdcgiuOHR4nZGUnHxPdIrMo6nXYOLTBZJuMZ%2Fk%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '787d11ca18d19fd7-SIN'}

# %% [markdown]
# ### Extracting and Creating Dataframe using loop and dict methods

# %%
data_json=rsp.json()
data_json
# Out:
# {'data': [{'resource': 'players',
#    'id': 2,
#    'country_id': 52126,
#    'firstname': 'Ahmed',
#    'lastname': 'Shehzad',
#    'fullname': 'Ahmed Shehzad',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/2/2.png',
#    'dateofbirth': '1991-11-23',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-31T05:00:31.000000Z'},
#   {'resource': 'players',
#    'id': 3,
#    'country_id': 52126,
#    'firstname': 'Anwar',
#    'lastname': 'Ali',
#    'fullname': 'Anwar Ali',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/3/3.png',
#    'dateofbirth': '1987-11-25',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-12-14T18:58:56.000000Z'},
#   {'resource': 'players',
#    'id': 4,
#    'country_id': 52126,
#    'firstname': 'Sarfraz',
#    'lastname': 'Ahmed',
#    'fullname': 'Sarfraz Ahmed',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/4/4.png',
#    'dateofbirth': '1987-05-22',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-07T08:51:02.000000Z'},
#   {'resource': 'players',
#    'id': 5,
#    'country_id': 52126,
#    'firstname': 'Azhar',
#    'lastname': 'Ali',
#    'fullname': 'Azhar Ali',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/5/5.png',
#    'dateofbirth': '1985-02-19',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-01T02:28:23.000000Z'},
#   {'resource': 'players',
#    'id': 6,
#    'country_id': 52126,
#    'firstname': 'Fakhar',
#    'lastname': 'Zaman',
#    'fullname': 'Fakhar Zaman',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/6/6.png',
#    'dateofbirth': '1990-04-10',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-02T02:22:22.000000Z'},
#   {'resource': 'players',
#    'id': 7,
#    'country_id': 52126,
#    'firstname': 'Imam',
#    'lastname': 'ul Haq',
#    'fullname': 'Imam ul Haq',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/7/7.png',
#    'dateofbirth': '1995-12-12',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-02T09:00:48.000000Z'},
#   {'resource': 'players',
#    'id': 8,
#    'country_id': 52126,
#    'firstname': 'Babar',
#    'lastname': 'Azam',
#    'fullname': 'Babar Azam',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/8/8.png',
#    'dateofbirth': '1994-10-15',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-23T10:47:44.000000Z'},
#   {'resource': 'players',
#    'id': 9,
#    'country_id': 52126,
#    'firstname': 'Asad',
#    'lastname': 'Shafiq',
#    'fullname': 'Asad Shafiq',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/9/9.png',
#    'dateofbirth': '1986-01-28',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-31T15:33:50.000000Z'},
#   {'resource': 'players',
#    'id': 10,
#    'country_id': 52126,
#    'firstname': 'Haris',
#    'lastname': 'Sohail',
#    'fullname': 'Haris Sohail',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/10/10.png',
#    'dateofbirth': '1989-01-09',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-02T07:30:27.000000Z'},
#   {'resource': 'players',
#    'id': 11,
#    'country_id': 52126,
#    'firstname': 'Usman',
#    'lastname': 'Salahuddin',
#    'fullname': 'Usman Salahuddin',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/11/11.png',
#    'dateofbirth': '1990-12-02',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-08T09:10:55.000000Z'},
#   {'resource': 'players',
#    'id': 12,
#    'country_id': 52126,
#    'firstname': 'Yasir',
#    'lastname': 'Shah',
#    'fullname': 'Yasir Shah',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/12/12.png',
#    'dateofbirth': '1986-05-02',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak-googly',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-09T05:17:13.000000Z'},
#   {'resource': 'players',
#    'id': 13,
#    'country_id': 52126,
#    'firstname': 'Shadab',
#    'lastname': 'Khan',
#    'fullname': 'Shadab Khan',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/13/13.png',
#    'dateofbirth': '1998-10-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-07T09:05:03.000000Z'},
#   {'resource': 'players',
#    'id': 14,
#    'country_id': 52126,
#    'firstname': 'Bilal',
#    'lastname': 'Asif',
#    'fullname': 'Bilal Asif',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/14/14.png',
#    'dateofbirth': '1985-09-24',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-01T03:31:48.000000Z'},
#   {'resource': 'players',
#    'id': 15,
#    'country_id': 52126,
#    'firstname': 'Mohammad',
#    'lastname': 'Abbas',
#    'fullname': 'Mohammad Abbas',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/15/15.png',
#    'dateofbirth': '1990-03-10',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-05T06:16:39.000000Z'},
#   {'resource': 'players',
#    'id': 16,
#    'country_id': 52126,
#    'firstname': 'Hasan',
#    'lastname': 'Ali',
#    'fullname': 'Hasan Ali',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/16/16.png',
#    'dateofbirth': '1994-07-02',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-02T08:29:31.000000Z'},
#   {'resource': 'players',
#    'id': 17,
#    'country_id': 52126,
#    'firstname': 'Wahab',
#    'lastname': 'Riaz',
#    'fullname': 'Wahab Riaz',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/17/17.png',
#    'dateofbirth': '1985-06-28',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'left-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-09T04:55:16.000000Z'},
#   {'resource': 'players',
#    'id': 18,
#    'country_id': 52126,
#    'firstname': 'Faheem',
#    'lastname': 'Ashraf',
#    'fullname': 'Faheem Ashraf',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/18/18.png',
#    'dateofbirth': '1994-01-16',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-02T02:19:32.000000Z'},
#   {'resource': 'players',
#    'id': 19,
#    'country_id': 52126,
#    'firstname': 'Mir',
#    'lastname': 'Hamza',
#    'fullname': 'Mir Hamza',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/19/19.png',
#    'dateofbirth': '1992-09-10',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'left-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-05T05:54:08.000000Z'},
#   {'resource': 'players',
#    'id': 20,
#    'country_id': 52126,
#    'firstname': 'Mohammad',
#    'lastname': 'Rizwan',
#    'fullname': 'Mohammad Rizwan',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/20/20.png',
#    'dateofbirth': '1992-01-01',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-02-23T10:41:51.000000Z'},
#   {'resource': 'players',
#    'id': 21,
#    'country_id': 52126,
#    'firstname': 'Mohammad',
#    'lastname': 'Hafeez',
#    'fullname': 'Mohammad Hafeez',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/21/21.png',
#    'dateofbirth': '1980-10-17',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-05T07:14:20.000000Z'},
#   {'resource': 'players',
#    'id': 22,
#    'country_id': 98,
#    'firstname': 'Tim',
#    'lastname': 'Paine',
#    'fullname': 'Tim Paine',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/22/22.png',
#    'dateofbirth': '1984-12-08',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-02-06T04:45:12.000000Z'},
#   {'resource': 'players',
#    'id': 23,
#    'country_id': 98,
#    'firstname': 'Ashton',
#    'lastname': 'Agar',
#    'fullname': 'Ashton Agar',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/23/23.png',
#    'dateofbirth': '1993-10-14',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-12-03T09:16:15.000000Z'},
#   {'resource': 'players',
#    'id': 24,
#    'country_id': 98,
#    'firstname': 'Brendan',
#    'lastname': 'Doggett',
#    'fullname': 'Brendan Doggett',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/24/24.png',
#    'dateofbirth': '1994-05-03',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-12-14T18:49:35.000000Z'},
#   {'resource': 'players',
#    'id': 25,
#    'country_id': 98,
#    'firstname': 'Aaron',
#    'lastname': 'Finch',
#    'fullname': 'Aaron Finch',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/25/25.png',
#    'dateofbirth': '1986-11-17',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-06T04:43:57.000000Z'},
#   {'resource': 'players',
#    'id': 26,
#    'country_id': 98,
#    'firstname': 'Travis',
#    'lastname': 'Head',
#    'fullname': 'Travis Head',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/26/26.png',
#    'dateofbirth': '1993-12-29',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-06T04:46:12.000000Z'},
#   {'resource': 'players',
#    'id': 27,
#    'country_id': 98,
#    'firstname': 'Jon',
#    'lastname': 'Holland',
#    'fullname': 'Jon Holland',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/27/27.png',
#    'dateofbirth': '1987-05-29',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:46:39.000000Z'},
#   {'resource': 'players',
#    'id': 28,
#    'country_id': 98,
#    'firstname': 'Usman',
#    'lastname': 'Khawaja',
#    'fullname': 'Usman Khawaja',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/28/28.png',
#    'dateofbirth': '1986-12-18',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-06T04:46:55.000000Z'},
#   {'resource': 'players',
#    'id': 29,
#    'country_id': 98,
#    'firstname': 'Marnus',
#    'lastname': 'Labuschagne',
#    'fullname': 'Marnus Labuschagne',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/29/29.png',
#    'dateofbirth': '1994-06-22',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak-googly',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-12-14T18:51:00.000000Z'},
#   {'resource': 'players',
#    'id': 30,
#    'country_id': 98,
#    'firstname': 'Nathan',
#    'lastname': 'Lyon',
#    'fullname': 'Nathan Lyon',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/30/30.png',
#    'dateofbirth': '1987-11-20',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:47:33.000000Z'},
#   {'resource': 'players',
#    'id': 31,
#    'country_id': 98,
#    'firstname': 'Mitchell',
#    'lastname': 'Marsh',
#    'fullname': 'Mitchell Marsh',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/31/31.png',
#    'dateofbirth': '1991-10-20',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-02-06T04:44:42.000000Z'},
#   {'resource': 'players',
#    'id': 32,
#    'country_id': 98,
#    'firstname': 'Shaun',
#    'lastname': 'Marsh',
#    'fullname': 'Shaun Marsh',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/0/32.png',
#    'dateofbirth': '1983-07-09',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-06T04:48:10.000000Z'},
#   {'resource': 'players',
#    'id': 33,
#    'country_id': 98,
#    'firstname': 'Michael',
#    'lastname': 'Neser',
#    'fullname': 'Michael Neser',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/1/33.png',
#    'dateofbirth': '1990-03-29',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2021-12-17T10:26:40.000000Z'},
#   {'resource': 'players',
#    'id': 34,
#    'country_id': 98,
#    'firstname': 'Matt',
#    'lastname': 'Renshaw',
#    'fullname': 'Matt Renshaw',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/2/34.png',
#    'dateofbirth': '1996-03-28',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-06T04:49:24.000000Z'},
#   {'resource': 'players',
#    'id': 35,
#    'country_id': 98,
#    'firstname': 'Peter',
#    'lastname': 'Siddle',
#    'fullname': 'Peter Siddle',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/3/35.png',
#    'dateofbirth': '1984-11-25',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:49:42.000000Z'},
#   {'resource': 'players',
#    'id': 36,
#    'country_id': 98,
#    'firstname': 'Mitchell',
#    'lastname': 'Starc',
#    'fullname': 'Mitchell Starc',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/4/36.png',
#    'dateofbirth': '1990-01-30',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'left-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:50:01.000000Z'},
#   {'resource': 'players',
#    'id': 37,
#    'country_id': 98,
#    'firstname': 'Alex',
#    'lastname': 'Carey',
#    'fullname': 'Alex Carey',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/5/37.png',
#    'dateofbirth': '1991-08-27',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-02-06T04:52:45.000000Z'},
#   {'resource': 'players',
#    'id': 38,
#    'country_id': 98,
#    'firstname': 'Nathan',
#    'lastname': 'Coulter-Nile',
#    'fullname': 'Nathan Coulter-Nile',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/6/38.png',
#    'dateofbirth': '1987-10-11',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:52:22.000000Z'},
#   {'resource': 'players',
#    'id': 39,
#    'country_id': 98,
#    'firstname': 'Chris',
#    'lastname': 'Lynn',
#    'fullname': 'Chris Lynn',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/7/39.png',
#    'dateofbirth': '1990-04-10',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-06T04:51:58.000000Z'},
#   {'resource': 'players',
#    'id': 40,
#    'country_id': 98,
#    'firstname': 'Glenn',
#    'lastname': 'Maxwell',
#    'fullname': 'Glenn Maxwell',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/8/40.png',
#    'dateofbirth': '1988-10-14',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-02-06T04:51:34.000000Z'},
#   {'resource': 'players',
#    'id': 41,
#    'country_id': 98,
#    'firstname': "D'Arcy",
#    'lastname': 'Short',
#    'fullname': "D'Arcy Short",
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/9/41.png',
#    'dateofbirth': '1990-08-09',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-02-06T04:51:19.000000Z'},
#   {'resource': 'players',
#    'id': 42,
#    'country_id': 98,
#    'firstname': 'Billy',
#    'lastname': 'Stanlake',
#    'fullname': 'Billy Stanlake',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/10/42.png',
#    'dateofbirth': '1994-11-04',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:53:23.000000Z'},
#   {'resource': 'players',
#    'id': 43,
#    'country_id': 98,
#    'firstname': 'Andrew',
#    'lastname': 'Tye',
#    'fullname': 'Andrew Tye',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/11/43.png',
#    'dateofbirth': '1986-12-12',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:50:40.000000Z'},
#   {'resource': 'players',
#    'id': 44,
#    'country_id': 98,
#    'firstname': 'Adam',
#    'lastname': 'Zampa',
#    'fullname': 'Adam Zampa',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/12/44.png',
#    'dateofbirth': '1992-03-31',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak-googly',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-06T04:53:02.000000Z'},
#   {'resource': 'players',
#    'id': 45,
#    'country_id': 98,
#    'firstname': 'Ben',
#    'lastname': 'McDermott',
#    'fullname': 'Ben McDermott',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/13/45.png',
#    'dateofbirth': '1994-12-12',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-02-06T04:50:22.000000Z'},
#   {'resource': 'players',
#    'id': 46,
#    'country_id': 153732,
#    'firstname': 'Virat',
#    'lastname': 'Kohli',
#    'fullname': 'Virat Kohli',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/14/46.png',
#    'dateofbirth': '1988-11-05',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-31T12:21:50.000000Z'},
#   {'resource': 'players',
#    'id': 47,
#    'country_id': 153732,
#    'firstname': 'Lokesh',
#    'lastname': 'Rahul',
#    'fullname': 'Lokesh Rahul',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/15/47.png',
#    'dateofbirth': '1992-04-18',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-04T05:07:39.000000Z'},
#   {'resource': 'players',
#    'id': 48,
#    'country_id': 153732,
#    'firstname': 'Prithvi',
#    'lastname': 'Shaw',
#    'fullname': 'Prithvi Shaw',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/16/48.png',
#    'dateofbirth': '1999-11-09',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-06T06:29:32.000000Z'},
#   {'resource': 'players',
#    'id': 49,
#    'country_id': 153732,
#    'firstname': 'Mayank',
#    'lastname': 'Agarwal',
#    'fullname': 'Mayank Agarwal',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/17/49.png',
#    'dateofbirth': '1991-02-16',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-31T11:40:37.000000Z'},
#   {'resource': 'players',
#    'id': 50,
#    'country_id': 153732,
#    'firstname': 'Cheteshwar',
#    'lastname': 'Pujara',
#    'fullname': 'Cheteshwar Pujara',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/18/50.png',
#    'dateofbirth': '1988-01-25',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-31T12:22:31.000000Z'},
#   {'resource': 'players',
#    'id': 51,
#    'country_id': 153732,
#    'firstname': 'Ajinkya',
#    'lastname': 'Rahane',
#    'fullname': 'Ajinkya Rahane',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/19/51.png',
#    'dateofbirth': '1988-06-06',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-31T07:21:37.000000Z'},
#   {'resource': 'players',
#    'id': 52,
#    'country_id': 153732,
#    'firstname': 'Hanuma',
#    'lastname': 'Vihari',
#    'fullname': 'Hanuma Vihari',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/20/52.png',
#    'dateofbirth': '1993-10-13',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-03-31T12:19:25.000000Z'},
#   {'resource': 'players',
#    'id': 53,
#    'country_id': 153732,
#    'firstname': 'Rishabh',
#    'lastname': 'Pant',
#    'fullname': 'Rishabh Pant',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/21/53.png',
#    'dateofbirth': '1997-10-04',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-09-17T15:11:33.000000Z'},
#   {'resource': 'players',
#    'id': 54,
#    'country_id': 153732,
#    'firstname': 'Ravichandran',
#    'lastname': 'Ashwin',
#    'fullname': 'Ravichandran Ashwin',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/22/54.png',
#    'dateofbirth': '1986-09-17',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2021-04-25T09:34:56.000000Z'},
#   {'resource': 'players',
#    'id': 55,
#    'country_id': 153732,
#    'firstname': 'Ravindra',
#    'lastname': 'Jadeja',
#    'fullname': 'Ravindra Jadeja',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/23/55.png',
#    'dateofbirth': '1988-12-06',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-03-31T11:45:09.000000Z'},
#   {'resource': 'players',
#    'id': 56,
#    'country_id': 153732,
#    'firstname': 'Kuldeep',
#    'lastname': 'Yadav',
#    'fullname': 'Kuldeep Yadav',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/24/56.png',
#    'dateofbirth': '1994-12-14',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'left-arm-chinaman',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-09-22T15:03:25.000000Z'},
#   {'resource': 'players',
#    'id': 57,
#    'country_id': 153732,
#    'firstname': 'Mohammed',
#    'lastname': 'Shami',
#    'fullname': 'Mohammed Shami',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/25/57.png',
#    'dateofbirth': '1990-09-03',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-03-31T12:22:11.000000Z'},
#   {'resource': 'players',
#    'id': 58,
#    'country_id': 153732,
#    'firstname': 'Umesh',
#    'lastname': 'Yadav',
#    'fullname': 'Umesh Yadav',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/26/58.png',
#    'dateofbirth': '1987-10-25',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-03-31T12:23:51.000000Z'},
#   {'resource': 'players',
#    'id': 59,
#    'country_id': 153732,
#    'firstname': 'Mohammed',
#    'lastname': 'Siraj',
#    'fullname': 'Mohammed Siraj',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/27/59.png',
#    'dateofbirth': '1994-03-13',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-05T07:39:51.000000Z'},
#   {'resource': 'players',
#    'id': 60,
#    'country_id': 153732,
#    'firstname': 'Shardul',
#    'lastname': 'Thakur',
#    'fullname': 'Shardul Thakur',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/28/60.png',
#    'dateofbirth': '1991-10-16',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-03-31T12:23:31.000000Z'},
#   {'resource': 'players',
#    'id': 61,
#    'country_id': 146,
#    'firstname': 'Jean-Paul',
#    'lastname': 'Duminy',
#    'fullname': 'Jean-Paul Duminy',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/29/61.png',
#    'dateofbirth': '1984-04-14',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-03T05:02:00.000000Z'},
#   {'resource': 'players',
#    'id': 62,
#    'country_id': 146,
#    'firstname': 'Reeza',
#    'lastname': 'Hendricks',
#    'fullname': 'Reeza Hendricks',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/30/62.png',
#    'dateofbirth': '1989-08-14',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-06T07:59:01.000000Z'},
#   {'resource': 'players',
#    'id': 63,
#    'country_id': 146,
#    'firstname': 'Imran',
#    'lastname': 'Tahir',
#    'fullname': 'Imran Tahir',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/31/63.png',
#    'dateofbirth': '1979-03-27',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak-googly',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-02T11:40:50.000000Z'},
#   {'resource': 'players',
#    'id': 64,
#    'country_id': 146,
#    'firstname': 'Christiaan',
#    'lastname': 'Jonker',
#    'fullname': 'Christiaan Jonker',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/0/64.png',
#    'dateofbirth': '1986-09-24',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-01T08:33:28.000000Z'},
#   {'resource': 'players',
#    'id': 65,
#    'country_id': 146,
#    'firstname': 'Heinrich',
#    'lastname': 'Klaasen',
#    'fullname': 'Heinrich Klaasen',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/1/65.png',
#    'dateofbirth': '1991-07-30',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-02T08:38:45.000000Z'},
#   {'resource': 'players',
#    'id': 66,
#    'country_id': 146,
#    'firstname': 'Aiden',
#    'lastname': 'Markram',
#    'fullname': 'Aiden Markram',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/2/66.png',
#    'dateofbirth': '1994-10-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-31T06:12:54.000000Z'},
#   {'resource': 'players',
#    'id': 68,
#    'country_id': 146,
#    'firstname': 'Lungi',
#    'lastname': 'Ngidi',
#    'fullname': 'Lungi Ngidi',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/4/68.png',
#    'dateofbirth': '1996-03-29',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-04T05:26:18.000000Z'},
#   {'resource': 'players',
#    'id': 69,
#    'country_id': 146,
#    'firstname': 'Andile',
#    'lastname': 'Phehlukwayo',
#    'fullname': 'Andile Phehlukwayo',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/5/69.png',
#    'dateofbirth': '1996-03-03',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-03-31T12:01:44.000000Z'},
#   {'resource': 'players',
#    'id': 70,
#    'country_id': 146,
#    'firstname': 'Kagiso',
#    'lastname': 'Rabada',
#    'fullname': 'Kagiso Rabada',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/6/70.png',
#    'dateofbirth': '1995-05-25',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-03T05:50:20.000000Z'},
#   {'resource': 'players',
#    'id': 71,
#    'country_id': 146,
#    'firstname': 'Tabraiz',
#    'lastname': 'Shamsi',
#    'fullname': 'Tabraiz Shamsi',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/7/71.png',
#    'dateofbirth': '1990-02-18',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-08T07:27:55.000000Z'},
#   {'resource': 'players',
#    'id': 72,
#    'country_id': 146,
#    'firstname': 'Dale',
#    'lastname': 'Steyn',
#    'fullname': 'Dale Steyn',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/8/72.png',
#    'dateofbirth': '1983-06-27',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-01T10:20:57.000000Z'},
#   {'resource': 'players',
#    'id': 73,
#    'country_id': 146,
#    'firstname': 'Khaya',
#    'lastname': 'Zondo',
#    'fullname': 'Khaya Zondo',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/9/73.png',
#    'dateofbirth': '1990-03-07',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-03T07:12:36.000000Z'},
#   {'resource': 'players',
#    'id': 74,
#    'country_id': 146,
#    'firstname': 'Dean',
#    'lastname': 'Elgar',
#    'fullname': 'Dean Elgar',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/10/74.png',
#    'dateofbirth': '1987-06-11',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-01T14:26:23.000000Z'},
#   {'resource': 'players',
#    'id': 75,
#    'country_id': 146,
#    'firstname': 'Faf',
#    'lastname': 'du Plessis',
#    'fullname': 'Faf du Plessis',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/11/75.png',
#    'dateofbirth': '1984-07-13',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2021-09-20T10:00:32.000000Z'},
#   {'resource': 'players',
#    'id': 76,
#    'country_id': 146,
#    'firstname': 'Junior',
#    'lastname': 'Dala',
#    'fullname': 'Junior Dala',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/12/76.png',
#    'dateofbirth': '1989-12-29',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-03T05:44:50.000000Z'},
#   {'resource': 'players',
#    'id': 77,
#    'country_id': 146,
#    'firstname': 'Quinton',
#    'lastname': 'de Kock',
#    'fullname': 'Quinton de Kock',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/13/77.png',
#    'dateofbirth': '1992-12-17',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-06T06:37:09.000000Z'},
#   {'resource': 'players',
#    'id': 79,
#    'country_id': 146,
#    'firstname': 'David',
#    'lastname': 'Miller',
#    'fullname': 'David Miller',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/15/79.png',
#    'dateofbirth': '1989-06-10',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-01T14:17:19.000000Z'},
#   {'resource': 'players',
#    'id': 80,
#    'country_id': 146,
#    'firstname': 'Dane',
#    'lastname': 'Paterson',
#    'fullname': 'Dane Paterson',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/16/80.png',
#    'dateofbirth': '1989-04-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-01T10:35:07.000000Z'},
#   {'resource': 'players',
#    'id': 81,
#    'country_id': 146,
#    'firstname': 'Gihahn',
#    'lastname': 'Cloete',
#    'fullname': 'Gihahn Cloete',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/17/81.png',
#    'dateofbirth': '1992-10-04',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-02T06:11:40.000000Z'},
#   {'resource': 'players',
#    'id': 82,
#    'country_id': 146,
#    'firstname': 'Rassie',
#    'lastname': 'van der Dussen',
#    'fullname': 'Rassie van der Dussen',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/18/82.png',
#    'dateofbirth': '1989-02-07',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-06T07:47:33.000000Z'},
#   {'resource': 'players',
#    'id': 83,
#    'country_id': 2325,
#    'firstname': 'Hamilton',
#    'lastname': 'Masakadza',
#    'fullname': 'Hamilton Masakadza',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/19/83.png',
#    'dateofbirth': '1983-08-09',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-02T07:18:27.000000Z'},
#   {'resource': 'players',
#    'id': 84,
#    'country_id': 2325,
#    'firstname': 'Solomon',
#    'lastname': 'Mire',
#    'fullname': 'Solomon Mire',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/20/84.png',
#    'dateofbirth': '1989-08-21',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-08T04:39:53.000000Z'},
#   {'resource': 'players',
#    'id': 85,
#    'country_id': 2325,
#    'firstname': 'Craig',
#    'lastname': 'Ervine',
#    'fullname': 'Craig Ervine',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/21/85.png',
#    'dateofbirth': '1985-08-19',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-01T09:51:06.000000Z'},
#   {'resource': 'players',
#    'id': 86,
#    'country_id': 2325,
#    'firstname': 'Brendan',
#    'lastname': 'Taylor',
#    'fullname': 'Brendan Taylor',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/22/86.png',
#    'dateofbirth': '1986-02-06',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-01T03:49:14.000000Z'},
#   {'resource': 'players',
#    'id': 87,
#    'country_id': 2325,
#    'firstname': 'Peter',
#    'lastname': 'Moor',
#    'fullname': 'Peter Moor',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/23/87.png',
#    'dateofbirth': '1991-02-02',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-06T05:57:40.000000Z'},
#   {'resource': 'players',
#    'id': 88,
#    'country_id': 2325,
#    'firstname': 'Elton',
#    'lastname': 'Chigumbura',
#    'fullname': 'Elton Chigumbura',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/24/88.png',
#    'dateofbirth': '1986-03-14',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-02T01:56:50.000000Z'},
#   {'resource': 'players',
#    'id': 89,
#    'country_id': 2325,
#    'firstname': 'Donald',
#    'lastname': 'Tiripano',
#    'fullname': 'Donald Tiripano',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/25/89.png',
#    'dateofbirth': '1988-03-17',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-01T17:34:44.000000Z'},
#   {'resource': 'players',
#    'id': 90,
#    'country_id': 2325,
#    'firstname': 'Kyle',
#    'lastname': 'Jarvis',
#    'fullname': 'Kyle Jarvis',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/26/90.png',
#    'dateofbirth': '1989-02-16',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-04T04:34:22.000000Z'},
#   {'resource': 'players',
#    'id': 91,
#    'country_id': 2325,
#    'firstname': 'Brandon',
#    'lastname': 'Mavuta',
#    'fullname': 'Brandon Mavuta',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/27/91.png',
#    'dateofbirth': '1997-03-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-01T03:47:18.000000Z'},
#   {'resource': 'players',
#    'id': 92,
#    'country_id': 2325,
#    'firstname': 'Richard',
#    'lastname': 'Ngarava',
#    'fullname': 'Richard Ngarava',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/28/92.png',
#    'dateofbirth': '1997-12-28',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'left-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-06T08:06:00.000000Z'},
#   {'resource': 'players',
#    'id': 93,
#    'country_id': 2325,
#    'firstname': 'Tinashe',
#    'lastname': 'Kamunhukamwe',
#    'fullname': 'Tinashe Kamunhukamwe',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/29/93.png',
#    'dateofbirth': '1995-07-10',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-08T08:03:23.000000Z'},
#   {'resource': 'players',
#    'id': 94,
#    'country_id': 2325,
#    'firstname': 'Wellington',
#    'lastname': 'Masakadza',
#    'fullname': 'Wellington Masakadza',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/30/94.png',
#    'dateofbirth': '1993-10-04',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-09T05:01:36.000000Z'},
#   {'resource': 'players',
#    'id': 95,
#    'country_id': 2325,
#    'firstname': 'Ryan',
#    'lastname': 'Murray',
#    'fullname': 'Ryan Murray',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/31/95.png',
#    'dateofbirth': '1998-03-30',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-06T12:50:03.000000Z'},
#   {'resource': 'players',
#    'id': 96,
#    'country_id': 2325,
#    'firstname': 'Tendai',
#    'lastname': 'Chatara',
#    'fullname': 'Tendai Chatara',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/0/96.png',
#    'dateofbirth': '1991-02-28',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-08T07:43:18.000000Z'},
#   {'resource': 'players',
#    'id': 97,
#    'country_id': 2325,
#    'firstname': 'Neville',
#    'lastname': 'Madziva',
#    'fullname': 'Neville Madziva',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/1/97.png',
#    'dateofbirth': '1991-08-02',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-06T04:42:13.000000Z'},
#   {'resource': 'players',
#    'id': 98,
#    'country_id': 2325,
#    'firstname': 'Chris',
#    'lastname': 'Mpofu',
#    'fullname': 'Chris Mpofu',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/2/98.png',
#    'dateofbirth': '1985-11-27',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-01T08:22:23.000000Z'},
#   {'resource': 'players',
#    'id': 99,
#    'country_id': 2325,
#    'firstname': 'Tarisai',
#    'lastname': 'Musakanda',
#    'fullname': 'Tarisai Musakanda',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/3/99.png',
#    'dateofbirth': '1994-10-31',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-08T07:39:29.000000Z'},
#   {'resource': 'players',
#    'id': 100,
#    'country_id': 24150873,
#    'firstname': 'Jason',
#    'lastname': 'Holder',
#    'fullname': 'Jason Holder',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/4/100.png',
#    'dateofbirth': '1991-11-05',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-03T04:52:51.000000Z'},
#   {'resource': 'players',
#    'id': 101,
#    'country_id': 24150873,
#    'firstname': 'Sunil',
#    'lastname': 'Ambris',
#    'fullname': 'Sunil Ambris',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/5/101.png',
#    'dateofbirth': '1993-03-23',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-11-10T13:40:06.000000Z'},
#   {'resource': 'players',
#    'id': 102,
#    'country_id': 24150873,
#    'firstname': 'Devendra',
#    'lastname': 'Bishoo',
#    'fullname': 'Devendra Bishoo',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/6/102.png',
#    'dateofbirth': '1985-11-06',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'legbreak',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-01T14:36:14.000000Z'},
#   {'resource': 'players',
#    'id': 103,
#    'country_id': 24150873,
#    'firstname': 'Kraigg',
#    'lastname': 'Brathwaite',
#    'fullname': 'Kraigg Brathwaite',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/7/103.png',
#    'dateofbirth': '1992-12-01',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-04T03:08:31.000000Z'},
#   {'resource': 'players',
#    'id': 104,
#    'country_id': 24150873,
#    'firstname': 'Roston',
#    'lastname': 'Chase',
#    'fullname': 'Roston Chase',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/8/104.png',
#    'dateofbirth': '1992-03-22',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-06T11:48:11.000000Z'},
#   {'resource': 'players',
#    'id': 105,
#    'country_id': 24150873,
#    'firstname': 'Shane',
#    'lastname': 'Dowrich',
#    'fullname': 'Shane Dowrich',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/9/105.png',
#    'dateofbirth': '1991-10-30',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
# ...
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/20/1364.png',
#    'dateofbirth': '1979-09-05',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-03-31T07:18:53.000000Z'},
#   {'resource': 'players',
#    'id': 1367,
#    'country_id': 52126,
#    'firstname': 'Zulfiqar',
#    'lastname': 'Babar',
#    'fullname': 'Zulfiqar Babar',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/23/1367.png',
#    'dateofbirth': '1978-12-10',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-09T05:35:25.000000Z'},
#   {'resource': 'players',
#    'id': 1370,
#    'country_id': 2817,
#    'firstname': 'Nathan',
#    'lastname': 'McCullum',
#    'fullname': 'Nathan McCullum',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/26/1370.png',
#    'dateofbirth': '1980-09-01',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-06T04:25:56.000000Z'},
#   {'resource': 'players',
#    'id': 1373,
#    'country_id': 52126,
#    'firstname': 'Rafatullah',
#    'lastname': 'Mohmand',
#    'fullname': 'Rafatullah Mohmand',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/29/1373.png',
#    'dateofbirth': '1976-11-06',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-06T06:42:47.000000Z'},
#   {'resource': 'players',
#    'id': 1376,
#    'country_id': 462,
#    'firstname': 'Steven',
#    'lastname': 'Finn',
#    'fullname': 'Steven Finn',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/0/1376.png',
#    'dateofbirth': '1989-04-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-08T05:01:29.000000Z'},
#   {'resource': 'players',
#    'id': 1379,
#    'country_id': 52126,
#    'firstname': 'Mohammad',
#    'lastname': 'Hasan',
#    'fullname': 'Mohammad Hasan',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/3/1379.png',
#    'dateofbirth': '1990-10-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-05T07:19:34.000000Z'},
#   {'resource': 'players',
#    'id': 1382,
#    'country_id': 52126,
#    'firstname': 'Rohail',
#    'lastname': 'Nazir',
#    'fullname': 'Rohail Nazir',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/6/1382.png',
#    'dateofbirth': '2001-10-10',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-06T09:09:32.000000Z'},
#   {'resource': 'players',
#    'id': 1385,
#    'country_id': 52126,
#    'firstname': 'Mohammad',
#    'lastname': 'Hasnain',
#    'fullname': 'Mohammad Hasnain',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/9/1385.png',
#    'dateofbirth': '2000-04-05',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-05T07:20:08.000000Z'},
#   {'resource': 'players',
#    'id': 1388,
#    'country_id': 52126,
#    'firstname': 'Khushdil',
#    'lastname': 'Shah',
#    'fullname': 'Khushdil Shah',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/12/1388.png',
#    'dateofbirth': '1995-02-07',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-10-30T10:20:34.000000Z'},
#   {'resource': 'players',
#    'id': 1391,
#    'country_id': 52126,
#    'firstname': 'Mohammad Irfan',
#    'lastname': 'Khan',
#    'fullname': 'Mohammad Irfan Khan',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/15/1391.png',
#    'dateofbirth': '1989-08-01',
#    'gender': 'm',
#    'battingstyle': None,
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2019-02-22T13:13:08.000000Z'},
#   {'resource': 'players',
#    'id': 1394,
#    'country_id': 52126,
#    'firstname': 'Mohammad',
#    'lastname': 'Arif',
#    'fullname': 'Mohammad Arif',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/placeholder.png',
#    'dateofbirth': '1994-01-02',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-05T07:23:17.000000Z'},
#   {'resource': 'players',
#    'id': 1397,
#    'country_id': 52126,
#    'firstname': 'Taimur',
#    'lastname': 'Sultan',
#    'fullname': 'Taimur Sultan',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/placeholder.png',
#    'dateofbirth': '1994-12-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-08T07:31:08.000000Z'},
#   {'resource': 'players',
#    'id': 1400,
#    'country_id': 52126,
#    'firstname': 'Khalid',
#    'lastname': 'Usman',
#    'fullname': 'Khalid Usman',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/placeholder.png',
#    'dateofbirth': '1986-03-01',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-03T07:09:37.000000Z'},
#   {'resource': 'players',
#    'id': 1403,
#    'country_id': 52126,
#    'firstname': 'Ibtisam',
#    'lastname': 'Sheikh',
#    'fullname': 'Ibtisam Sheikh',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/27/1403.png',
#    'dateofbirth': '1999-03-16',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'legbreak-googly',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-02T08:55:29.000000Z'},
#   {'resource': 'players',
#    'id': 1406,
#    'country_id': 52126,
#    'firstname': 'Umaid',
#    'lastname': 'Asif',
#    'fullname': 'Umaid Asif',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/placeholder.png',
#    'dateofbirth': '1984-04-30',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-23T10:41:40.000000Z'},
#   {'resource': 'players',
#    'id': 1409,
#    'country_id': 52126,
#    'firstname': 'Sameen',
#    'lastname': 'Gul',
#    'fullname': 'Sameen Gul',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/1/1409.png',
#    'dateofbirth': '1999-02-04',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-07T07:59:13.000000Z'},
#   {'resource': 'players',
#    'id': 1412,
#    'country_id': 52126,
#    'firstname': 'Saif',
#    'lastname': 'Badar',
#    'fullname': 'Saif Badar',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/4/1412.png',
#    'dateofbirth': '1998-07-03',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'legbreak-googly',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-07T07:48:56.000000Z'},
#   {'resource': 'players',
#    'id': 1415,
#    'country_id': 52126,
#    'firstname': 'Ghulam',
#    'lastname': 'Mudassar',
#    'fullname': 'Ghulam Mudassar',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/7/1415.png',
#    'dateofbirth': '1999-10-24',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'left-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-02T06:10:09.000000Z'},
#   {'resource': 'players',
#    'id': 1418,
#    'country_id': 52126,
#    'firstname': 'Sohail',
#    'lastname': 'Akhtar',
#    'fullname': 'Sohail Akhtar',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/10/1418.png',
#    'dateofbirth': '1986-03-02',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-08T04:38:40.000000Z'},
#   {'resource': 'players',
#    'id': 1421,
#    'country_id': 52126,
#    'firstname': 'Salman',
#    'lastname': 'Irshad',
#    'fullname': 'Salman Irshad',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/13/1421.png',
#    'dateofbirth': '1995-03-12',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-07T07:53:41.000000Z'},
#   {'resource': 'players',
#    'id': 1424,
#    'country_id': 52126,
#    'firstname': 'Gulraiz',
#    'lastname': 'Sadaf',
#    'fullname': 'Gulraiz Sadaf',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/16/1424.png',
#    'dateofbirth': '1989-12-27',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 3, 'name': 'Wicketkeeper'},
#    'updated_at': '2020-04-02T07:12:10.000000Z'},
#   {'resource': 'players',
#    'id': 1427,
#    'country_id': 52126,
#    'firstname': 'Raza',
#    'lastname': 'Hasan',
#    'fullname': 'Raza Hasan',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/19/1427.png',
#    'dateofbirth': '1992-07-08',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-06T07:54:40.000000Z'},
#   {'resource': 'players',
#    'id': 1430,
#    'country_id': 52126,
#    'firstname': 'Khurram',
#    'lastname': 'Manzoor',
#    'fullname': 'Khurram Manzoor',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/22/1430.png',
#    'dateofbirth': '1986-06-10',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-03T07:18:56.000000Z'},
#   {'resource': 'players',
#    'id': 1433,
#    'country_id': 38404,
#    'firstname': 'Mahela',
#    'lastname': 'Jayawardene',
#    'fullname': 'Mahela Jayawardene',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/25/1433.png',
#    'dateofbirth': '1977-05-27',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-04-04T05:44:42.000000Z'},
#   {'resource': 'players',
#    'id': 1436,
#    'country_id': 5790,
#    'firstname': 'David',
#    'lastname': 'Wiese',
#    'fullname': 'David Wiese',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/28/1436.png',
#    'dateofbirth': '1985-06-18',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2022-08-01T11:57:05.000000Z'},
#   {'resource': 'players',
#    'id': 1442,
#    'country_id': 52126,
#    'firstname': 'Danish',
#    'lastname': 'Aziz',
#    'fullname': 'Danish Aziz',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/placeholder.png',
#    'dateofbirth': '1995-11-20',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-01T11:45:16.000000Z'},
#   {'resource': 'players',
#    'id': 1445,
#    'country_id': 52126,
#    'firstname': 'Kashif',
#    'lastname': 'Bhatti',
#    'fullname': 'Kashif Bhatti',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/5/1445.png',
#    'dateofbirth': '1986-07-25',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'slow-left-arm-orthodox',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-03T06:06:50.000000Z'},
#   {'resource': 'players',
#    'id': 1448,
#    'country_id': 52126,
#    'firstname': 'Tabish',
#    'lastname': 'Khan',
#    'fullname': 'Tabish Khan',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/8/1448.png',
#    'dateofbirth': '1984-12-12',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-04-08T07:27:40.000000Z'},
#   {'resource': 'players',
#    'id': 1451,
#    'country_id': 52126,
#    'firstname': 'Hasan',
#    'lastname': 'Mohsin',
#    'fullname': 'Hasan Mohsin',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/11/1451.png',
#    'dateofbirth': '1998-01-11',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 4, 'name': 'Allrounder'},
#    'updated_at': '2020-04-02T08:30:50.000000Z'},
#   {'resource': 'players',
#    'id': 1454,
#    'country_id': 52126,
#    'firstname': 'Noor',
#    'lastname': 'Wali',
#    'fullname': 'Noor Wali',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/placeholder.png',
#    'dateofbirth': '1996-08-28',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-02-04T10:03:07.000000Z'},
#   {'resource': 'players',
#    'id': 1457,
#    'country_id': 52126,
#    'firstname': 'Abrar',
#    'lastname': 'Ahmad',
#    'fullname': 'Abrar Ahmad',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/17/1457.png',
#    'dateofbirth': '1998-10-16',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': None,
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-03-30T15:51:57.000000Z'},
#   {'resource': 'players',
#    'id': 1460,
#    'country_id': 52126,
#    'firstname': 'Abdullah',
#    'lastname': 'Shafique',
#    'fullname': 'Abdullah Shafique',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/20/1460.png',
#    'dateofbirth': '1999-11-20',
#    'gender': 'm',
#    'battingstyle': 'right-hand-bat',
#    'bowlingstyle': 'right-arm-offbreak',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-03-30T15:35:15.000000Z'},
#   {'resource': 'players',
#    'id': 1463,
#    'country_id': 52126,
#    'firstname': 'Abdul',
#    'lastname': 'Ameer',
#    'fullname': 'Abdul Ameer',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/23/1463.png',
#    'dateofbirth': '1992-03-20',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'left-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 2, 'name': 'Bowler'},
#    'updated_at': '2020-03-30T15:27:32.000000Z'},
#   {'resource': 'players',
#    'id': 1466,
#    'country_id': 462,
#    'firstname': 'Ross',
#    'lastname': 'Whiteley',
#    'fullname': 'Ross Whiteley',
#    'image_path': 'https://cdn.sportmonks.com/images/cricket/players/26/1466.png',
#    'dateofbirth': '1988-09-13',
#    'gender': 'm',
#    'battingstyle': 'left-hand-bat',
#    'bowlingstyle': 'left-arm-fast-medium',
#    'position': {'resource': 'positions', 'id': 1, 'name': 'Batsman'},
#    'updated_at': '2020-09-11T18:21:59.000000Z'},
#   ...]}

# %%
id=[]
country_id=[]
firstname=[]
lastname=[]
fullname=[]
gender=[]
battingstyle=[]
bowlingstyle=[]
player_type=[]
playing_position=[]
DOB=[]

# %%
for i in range(len(data_json['data'])):
    id.append(data_json['data'][i]['id'])
    country_id.append(data_json['data'][i]['country_id'])
    firstname.append(data_json['data'][i]['firstname'])
    lastname.append(data_json['data'][i]['lastname'])
    fullname.append(data_json['data'][i]['fullname'])
    DOB.append(data_json['data'][i]['dateofbirth'])
    gender.append(data_json['data'][i]['gender'])
    battingstyle.append(data_json['data'][i]['battingstyle'])
    bowlingstyle.append(data_json['data'][i]['bowlingstyle'])
    player_type.append(data_json['data'][i]['position']['name'])
    playing_position.append(data_json['data'][i]['position']['id'])

# %%
L = list(map(list, zip(id,country_id,firstname,lastname,fullname,gender,battingstyle,bowlingstyle,player_type,playing_position,DOB)))
players_df = pd.DataFrame(L, columns=['ID', 'country_id', 'firstname','lastname','fullname','gender','battingstyle','bowlingstyle','player_type','playing_position','DOB'])
players_df.head()
# Out:
#    ID  country_id firstname lastname       fullname gender    battingstyle  \
# 0   2       52126     Ahmed  Shehzad  Ahmed Shehzad      m  right-hand-bat
# 1   3       52126     Anwar      Ali      Anwar Ali      m  right-hand-bat
# 2   4       52126   Sarfraz    Ahmed  Sarfraz Ahmed      m  right-hand-bat
# 3   5       52126     Azhar      Ali      Azhar Ali      m  right-hand-bat
# 4   6       52126    Fakhar    Zaman   Fakhar Zaman      m   left-hand-bat
#
#              bowlingstyle   player_type  playing_position         DOB
# 0                legbreak       Batsman                 1  1991-11-23
# 1   right-arm-fast-medium        Bowler                 2  1987-11-25
# 2      right-arm-offbreak  Wicketkeeper                 3  1987-05-22
# 3                legbreak       Batsman                 1  1985-02-19
# 4  slow-left-arm-orthodox       Batsman                 1  1990-04-10

# %%
players_df.to_csv('S:/Datasets/csv/cricket_ETL_using_api.csv',index=False)

# %%
players_df.shape
# Out:
# (15168, 11)

# %% [markdown]
# ### Using Pandas json_normalize() method

# %%
df=pd.json_normalize(data_json['data'])
df.shape
# Out:
# (15168, 15)

# %%
df.head()
# Out:
#   resource  id  country_id firstname lastname       fullname  \
# 0  players   2       52126     Ahmed  Shehzad  Ahmed Shehzad
# 1  players   3       52126     Anwar      Ali      Anwar Ali
# 2  players   4       52126   Sarfraz    Ahmed  Sarfraz Ahmed
# 3  players   5       52126     Azhar      Ali      Azhar Ali
# 4  players   6       52126    Fakhar    Zaman   Fakhar Zaman
#
#                                           image_path dateofbirth gender  \
# 0  https://cdn.sportmonks.com/images/cricket/play...  1991-11-23      m
# 1  https://cdn.sportmonks.com/images/cricket/play...  1987-11-25      m
# 2  https://cdn.sportmonks.com/images/cricket/play...  1987-05-22      m
# 3  https://cdn.sportmonks.com/images/cricket/play...  1985-02-19      m
# 4  https://cdn.sportmonks.com/images/cricket/play...  1990-04-10      m
#
#      battingstyle            bowlingstyle                   updated_at  \
# 0  right-hand-bat                legbreak  2020-03-31T05:00:31.000000Z
# 1  right-hand-bat   right-arm-fast-medium  2020-12-14T18:58:56.000000Z
# 2  right-hand-bat      right-arm-offbreak  2020-04-07T08:51:02.000000Z
# 3  right-hand-bat                legbreak  2020-04-01T02:28:23.000000Z
# 4   left-hand-bat  slow-left-arm-orthodox  2020-04-02T02:22:22.000000Z
#
#   position.resource  position.id position.name
# 0         positions            1       Batsman
# 1         positions            2        Bowler
# 2         positions            3  Wicketkeeper
# 3         positions            1       Batsman
# 4         positions            1       Batsman

# %%
df.to_csv('S:/Datasets/csv/cricket_ETL_using_api_json_normalize.csv',index=False)

# %% [markdown]
# #### End of this Notebook;
# Author: < Shafi Mohiddin Shaik><hr>
# LinkedIn:[Click Here to Shafi's Linkedin Page](https://www.linkedin.com/in/shafi-shaik-0279651b0)
