# %%
import requests
from bs4 import BeautifulSoup

# %%
url1="https://unifiedportal-epfo.epfindia.gov.in/publicPortal/no-auth/misReport/home/loadEstSearchHome"
req=requests.get(url1)
req
# Out:
# <Response [200]>

# %%
req.status_code
# Out:
# 200

# %%
req.headers
# Out:
# {'Date': 'Thu, 15 Dec 2022 05:33:09 GMT', 'Server': 'Apache', 'Content-Security-Policy': "frame-ancestors 'self';, default-src 'self'; script-src 'self' 'unsafe-eval' 'unsafe-inline' https://code.jquery.com https://maxcdn.bootstrapcdn.com https://cdnjs.cloudflare.com https://ajax.googleapis.com/ajax/libs/jquery/2.2.4/jquery.min.js https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js https://cdn.datatables.net/1.10.12/js/dataTables.bootstrap.min.js; connect-src 'self'; style-src 'self' 'unsafe-inline' https://maxcdn.bootstrapcdn.com https://cdnjs.cloudflare.com; font-src 'self' https://maxcdn.bootstrapcdn.com; object-src 'self'; media-src 'self'; frame-src 'self'; frame-ancestors 'self'; child-src 'self'; form-action 'self';", 'X-XSS-Protection': '1; mode=block, 1; mode=block', 'X-Content-Type-Options': 'nosniff, nosniff', 'X-FRAME-OPTIONS': 'SAMEORIGIN', 'Cache-Control': 'no-cache, private', 'Set-Cookie': 'key=value; HttpOnly; Secure; SameSite=strict, JSESSIONID=web
# ...

# %%
req.encoding
# Out:
# 'UTF-8'

# %%
req.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
data=BeautifulSoup(req.text,'html.parser')

# %%
data
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="max-age=0, must-revalidate, no-cache, no-store, private" http-equiv="cache-control"/>
# <meta content="-1" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <title>EPFO:Establishment Search</title>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <link href="/publicPortal/styles/epfo-style.css" rel="stylesheet">
# ...
